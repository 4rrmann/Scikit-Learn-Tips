# %% [markdown]
# *need to **impute missing values for a categorical feature?***<br>
# *two options:*<br>
# 1. *impute the most frequent value*
# 2. *impute the value `missing`, which treats it as a separate category*

# %%
import pandas as pd
X = pd.DataFrame({
    "Shape": ["square", "square", "oval", "oval", "circle", None]
})

X
# Out:
#     Shape
# 0  square
# 1  square
# 2    oval
# 3    oval
# 4  circle
# 5     NaN

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy='most_frequent')
X_imputed = imputer.fit_transform(X)

# %%
X_imputed
# Out:
# array([['square'],
#        ['square'],
#        ['oval'],
#        ['oval'],
#        ['circle'],
#        ['oval']], dtype=object)

# %%
imputer = SimpleImputer(strategy='constant', fill_value='missing')
X_imputed = imputer.fit_transform(X)
X_imputed
# Out:
# array([['square'],
#        ['square'],
#        ['oval'],
#        ['oval'],
#        ['circle'],
#        ['missing']], dtype=object)
