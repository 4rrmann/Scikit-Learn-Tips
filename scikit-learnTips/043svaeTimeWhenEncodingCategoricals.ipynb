# %% [markdown]
# *with a **tree-based mdoel, try OrdinalEncoder** instead of OneHotEncoder even for a nominal(unordered) feeatures*<br>
# *Accuracy will often be similar, but OrdinalEncoder will be much faster!*

# %%
import pandas as pd
import seaborn as sns

df = sns.load_dataset('titanic')

sdf = df[['sex', 'who', 'embarked', 'embark_town', 'class', 'survived']]
sdf = sdf.dropna()

X = sdf.drop('survived', axis=1)
y = sdf['survived']

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.1, random_state=42)

# %%
#OneHotEncoder creates 14 columns(by variations)
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder()
ohe.fit_transform(X).shape
# Out:
# (889, 14)

# %%
#OrdinalEncoder creates 5columns(as it is)
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder()
oe.fit_transform(X).shape
# Out:
# (889, 5)

# %%
#Random Forests is a tree-based model
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state=1, n_jobs=1)

# %%
#pipeline containing OneHotEncoder
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import cross_val_score
ohe_pipe = make_pipeline(ohe, rf)
# %time cross_val_score(ohe_pipe, X,y).mean()
# Out:
# CPU times: total: 1.38 s
# Wall time: 1.47 s
# np.float64(0.8211578746905352)

# %%
#pipeline containing OrdinalEncoder
oe_pipe = make_pipeline(oe, rf)
# %time cross_val_score(oe_pipe, X,y).mean()
# Out:
# CPU times: total: 1.28 s
# Wall time: 1.33 s
# np.float64(0.8211578746905352)
