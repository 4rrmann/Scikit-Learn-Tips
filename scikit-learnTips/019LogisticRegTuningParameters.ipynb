# %% [markdown]
# *some **important tuning Parameters for Logestic Regression:***
# * ***C:** inverse of regularization strength*
# * ***penalty:** type of rgeularization*
# * ***solver:** algorithm used for optimization*

# %% [markdown]
# ![image.png](attachment:image.png)
